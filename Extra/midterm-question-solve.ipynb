# %%
#number 1
string_1=input("Enter the string 1: ").split(" ")
string_2=input("Enter the string 2: ").split(' ')
x=len(string_1)
y=len(string_2)

number_of_common_words=0

for i in range(len(string_1)):
    for j in range(len(string_2)):
        if string_1[i]==string_2[j]:
            number_of_common_words+=1

z=(number_of_common_words/(x+y))*100
if z>=30:
    print("Common percentage: ",z,"%")
    print("Plagiarism detected.")
else:
    print("Common percentage: ",z,"%")
    print("Good job1")
# Out:
# Enter the string 1: bob is my dog’s name
# Enter the string 2: my dog is a canine
# Common percentage:  20.0 %
# Good job1

# %%
#number2
#Todo
string_1=input("Enter the string: ")
L=-1
R=+1
U=+1
D=-1
x=0
y=0

for i in range(len(string_1)):
    if string_1[i]=="L":
        x=x-1
    elif string_1[i]=="R":
        x+=1
    elif string_1[i]=="U":
        y+=1
    elif string_1[i]=="D":
        y=y-1
print("Final position at",(x,y))

# %%
#number 3
string_1="kelvin@yahoo.com"
gmail="gmail.com"
yahoo="@yahoo.com"
Gsuit="@g.bracu.com"


if gmail in string_1:
    print("gmail")
elif  yahoo in string_1 :
    print("yahoo")
elif   Gsuit in string_1:
    print("Gsuit")
else:
    print("No")

# %%
#number4

string_1=input("Enter the string: ")
uppyer_latter=''
lower_latter=''
for i in string_1:
    if i>="A" and i<="Z":
        upper_latter+=i
    elif "a"<=i<="z":
        lower_latter+=i
flag=False
for i in range(len(string_1)-2):
    
    if string_1[i] in upper_latter  and  string_1[i+1] in upper_latter and string_1[i+2] in upper_latter:
        flag=True
        break
    else:
        flage=False
if flag==True:
    print(upper_latter)
else:
    print(lower_latter)

# %%
#number5


string_1=input("Enter the string: ")
upper_latter=''
lower_latter=''
for i in string_1:
    if i>="A" and i<="Z":
        upper_latter+=i
    elif "a"<=i<="z":
        lower_latter+=i
count=0
for i in string_1:
    
    if i in upper_latter  :
        count+=1
        if count==3:
            break
    
        
    else:
        count=0
if count==3:
    print(upper_latter)
else:
    print(lower_latter)

# %%
#number 6
#Todo
string_1=input("enter the string: ")
list1=[]

while string_1!="STOP":
    list1.append(string_1)
    string_1=input("enter the string: ")
for i in range(len(list1)):
    print(list1[i]*(i+1))

# %%
#number 7
#Todo 
p="hello_there!"
n=3
s="he!"
counter=0
for i in p:
    counter+=1
flag=False
for j in p:
    if counter>=n:
        if j in s:
            if j not in " ":
                flag=True
            else:
                flag=False
        else:
            flag=False
    else:
        flag=False
if flag==True:
    print("valid password")
else:
    print("invalid passward")

# %%
#number 8
#Todo
n=int(input("Enter the number: "))
for i in range(n+1):
    
    if i==1:
        print("=== Iteration 1 ===")
        print(i)
        
    elif i==2:
        print("=== Iteration 2===")
        for line in range(i+1):
            for col in range(line):
                print("x",end="")
            print()
        
    elif i==3:
        print("=== Iteration 3===")
        for line in range(1,i+1):
            for col in range(1,i+1):
                print(col,end='')
            print()
        
    elif i==4:
        print("=== Iteration 4 ===")
        for line in range(i+1):
            for col in range(line):
                print("x",end='')
            print()
        
    elif i==5:
        print("=== Iteration 5 ===")
        for line in range(1,i+1):
            for col in range(1,i+1):
                print(col,end="")
            print()

# %%
#number 9
string_1 = input("Enter the string: ")
num = int(input("Enter the number: "))
x=''
pos = 1
for i in range(len(string_1)):

    if num % 2 == 0:
        if pos % 2 != 0:
            y = chr((ord(string_1[i]) + 1)-32)
            x += y
    else:
        if pos % 2 == 0:
            
            y = chr((ord(string_1[i]) + 1)-32)
            x += y
    pos += 1
print(x)

# %%
#number 10
#Todo
number=int(input("Enter the numbe: "))
while number!=0:
    result=number%10
    if result%2==0:
        print(result,end="")
    number=number//10

# %%
#number11
#Todo
string_1=input("enter the string: ")
list1=[]

for i in range(len(string_1)):
    list1.append(string_1[i])
x1 = ''
for i in range(len(list1)):
    if list1[i]==" ":
        x1+=string_1[i]
    elif list1.count(string_1[i]) == 3:

        y = ord(string_1[i]) + 3
        x1 += chr(y)
    elif list1.count(string_1[i])==2:

        y=ord(string_1[i])+2
        x1+=chr(y)
    elif list1.count(string_1[i])==1:

        y = ord(string_1[i]) + 1
        x1+=chr(y)
print(x1)

# %%
#number 12
#Todo
n1=int(input("enter the numbe: "))
n2=int(input("enter the number: "))
for line in range(1,n1+1):
    for col in range(1,n2+1):
        if line>=col:
            print(col,end=" ")
        else:
            print("=",end=" ")
    print()

# %%
#number 13
#Todo
string_1="python notebook"
pos=0
x=''
for i in range(len(string_1)):
    if pos%3==0:
        x+=chr(ord(string_1[i])-32)
    elif string_1[i]==" ":
        x+=string_1[i]
    else:
        x+=string_1[i]
    pos+=1
print(x)

# %%
#number 14
#Todo
string_1="oello"
str1="o"
flag=False
for i in range(len(string_1)):
    if string_1[0] in str1 and string_1[-1] in str1:
        flag=True
    else:
        flaf=False
if flag==True:
    print("yes")
else:
    print("No")
