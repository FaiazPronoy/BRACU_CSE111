# %%
class Store:
 
  def __init__(self, name, price):
    self.__app_name = name
    self.__price = price  
  
  def getName(self):
    return self.__app_name
 
  def __str__(self):
    return 'App name:' + self.__app_name + '\nPrice:$' + str(self.__price) 
 
class AppStore(Store):
  apps = 0
  price = 0
  def print_details():
    print(f"Total number of apps in App Store: {AppStore.apps}")
    print(f"Total price: ${AppStore.price}")
  @classmethod
  def initiate(self, *args):
    if len(args) == 1:
      self.name = args[0]
      self.price = 0
      self.year = 2010
    print("Installed the Spotify app for free from the App Store.")
    return(f"App name: {self.name} \nPrice: ${self.price} Year: {self.year}")



  def __init__(self, *args2):
    pass

class PlayStore(AppStore):
  def print_details(self):
    pass

  @classmethod
  def initiate(self, *args):
    if len(args) == 1:
      self.name = args[0]
      self.price = 0
      self.year = 2010
    print(f"App name: {self.name} \nPrice: ${self.price} Year: {self.year}")










AppStore.print_details()
print('*****************************')
app1 = AppStore.initiate('Spotify')
print(app1)
print('*****************************')
app2 = AppStore('Lightroom Pro', 3 , 2015 )
print(app2)
print('*****************************')
app3 = PlayStore.initiate('Mail',2012)
print(app3)
print('*****************************')
app4 = PlayStore('Footej Camera Pro', 5, 2018 )
print(app4)
print('*****************************')
app5 = AppStore('GarageBand', 12 , 2016 )
print(app2)
print('*****************************')
AppStore.print_details()
print('*****************************')
PlayStore.print_details()
# Out:
# Total number of apps in App Store: 0
# Total price: $0
# *****************************
# Installed the Spotify app for free from the App Store.
# App name: Spotify
# Price: $0 Year: 2010
# *****************************
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-8024f11af329> in <module>
#      58 print('*****************************')
#      59 app2 = AppStore('Lightroom Pro', 3 , 2015 )
# ---> 60 print(app2)
#      61 print('*****************************')
#      62 app3 = PlayStore.initiate('Mail',2012)
#
# <ipython-input-28-8024f11af329> in __str__(self)
#       9
#      10   def __str__(self):
# ---> 11     return 'App name:' + self.__app_name + '\nPrice:$' + str(self.__price)
#      12
#      13 class AppStore(Store):
#
# AttributeError: 'AppStore' object has no attribute '_Store__app_name'
